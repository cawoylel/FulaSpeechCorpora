# %%
# !pip install scrapy
# !apt install libicu-dev pkg-config
# !pip install ICU-Tokenizer
# Out:
# Requirement already satisfied: scrapy in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (2.8.0)
# Requirement already satisfied: Twisted>=18.9.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=3.4.6 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (41.0.7)
# Requirement already satisfied: cssselect>=0.9.1 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (23.3.0)
# Requirement already satisfied: queuelib>=1.4.2 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (21.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (2.1.2)
# Requirement already satisfied: zope.interface>=5.1.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: protego>=0.1.15 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: itemadapter>=0.1.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: setuptools in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (68.2.2)
# Requirement already satisfied: packaging in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (23.2)
# Requirement already satisfied: tldextract in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (5.1.1)
# Requirement already satisfied: lxml>=4.3.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: cffi>=1.12 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from cryptography>=3.4.6->scrapy) (1.16.0)
# Requirement already satisfied: jmespath>=0.9.5 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1-modules in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Requirement already satisfied: pyasn1 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from service-identity>=18.1.0->scrapy) (0.5.1)
# Requirement already satisfied: six in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from service-identity>=18.1.0->scrapy) (1.16.0)
# Requirement already satisfied: constantly>=15.1 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: Automat>=0.8.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from Twisted>=18.9.0->scrapy) (4.9.0)
# Requirement already satisfied: idna in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from tldextract->scrapy) (3.6)
# Requirement already satisfied: requests>=2.1.0 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: pycparser in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from requests>=2.1.0->tldextract->scrapy) (2023.11.17)
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
#
# Requirement already satisfied: ICU-Tokenizer in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: tqdm in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from ICU-Tokenizer) (4.66.1)
# Requirement already satisfied: PyICU in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from ICU-Tokenizer) (2.12)
# Requirement already satisfied: regex in /Users/yysy/opt/miniconda3/envs/scraper/lib/python3.8/site-packages (from ICU-Tokenizer) (2023.12.25)

# %%
from pathlib import Path
import requests
from scrapy import Spider, Request
from scrapy.crawler import CrawlerProcess
from icu_tokenizer import SentSplitter
import yaml

# %%
SPLITTER = SentSplitter("ff")

# %%
class MySpider(Spider):
    name = "bible"
    with open("../../extra/links.yml") as links_file:
        links = yaml.safe_load(links_file)
    languages, start_urls = zip(*links.items())
    codes = [url.split(".")[-1] for url in start_urls]
    mapping = dict(zip(codes, languages))

    def download_audio(self, audio_src, output_file):
        data = requests.get(audio_src)
        with open(output_file, 'wb') as out_mp3:
            out_mp3.write(data.content)
            return True, Path(output_file).stem

    def parse(self, response):
        content_to_pass = {"ChapterContent_r___3KRx", "ChapterContent_label__R2PLt", "ChapterContent_note__YlDW0",
                           "ChapterContent_fr__0KsID", "ChapterContent_body__O3qjr", "ft", "w"}
        title = response.css("h1::text")
        title = title.get()
        book, chapter, code = response.url.split("/")[-1].split(".")[-3:]
        language = MySpider.mapping[code]

        output_folder = Path(f"../../bible/raw/{language}")
        output_folder.mkdir(exist_ok=True, parents=True)
        output_filename = output_folder / f"{book}_{chapter}_{code}"

        with open(f"../../bible/{code}.books", "a+") as titles:
            titles.write(f"{book}\t{chapter}\t{title}\n")
        audio = response.css("div.pli-1:nth-child(4) > div:nth-child(1) > audio:nth-child(1)")
        if "src" in audio.attrib:
            audio = audio.attrib["src"]
            self.download_audio(audio, f"{output_filename}.mp3")
        with open(f"{output_filename}.txt", "w") as output_file:
            output_file.write(f"{title}\n")
            for content in response.css("div.ChapterContent_chapter__uvbXo div"):
                if content.attrib["class"] in content_to_pass:
                    continue
                spans = content.css("span span")
                if not spans:
                    text = " ".join(verse.strip() for verse in content.css("span *::text").getall())
                    text = text.strip()
                    if not text:
                        continue
                    for sent in SPLITTER.split(text):
                        output_file.write(f"{sent}\n")
                    continue
                verses = []
                for span in spans:
                    if span.attrib["class"] in content_to_pass:
                        continue
                    for verse in span.css("*::text").getall():
                        verses.append(verse.strip())
                text = " ".join(verses).strip()
                text = text.strip()
                if not text:
                    continue
                for sent in SPLITTER.split(text):
                    output_file.write(f"{sent}\n")
        next_page = response.css("div.\[pointer-events\:all\]:nth-child(2) > a:nth-child(1)")
        if next_page:
            yield Request(url=f"https://www.bible.com{next_page.attrib['href']}")

# %%
# %%capture
process = CrawlerProcess()

process.crawl(MySpider, name="bible")
process.start()
